# %%
import sys
import os

sys.path.append(os.path.abspath("../../src"))

from data.load_data import load_data

chocolate_df = load_data("../../data/processed/chocolate_price.csv")

dark_chocolates = chocolate_df[chocolate_df["Cocoa Percent"] > 70].reset_index()

has_Trinitario = dark_chocolates["Bean Type"].str.contains("Trinitario", case=False, na=False)

for idx, val in enumerate(has_Trinitario):
    if val == True:
        ten_percent = dark_chocolates.iloc[idx]["price(100g)"] / 10
        dark_chocolates.at[idx, "price(100g)"] += ten_percent

priceSum = dark_chocolates["price(100g)"].sum()


dark_chocolates.to_csv("../../data/processed/dark_chocolates.csv")

dark_chocolates
# Out:
#      index             Company                      Specific Bean Origin  \
# 0       26                 Adi                        Vanua Levu, Toto-A
# 1       27                 Adi                                Vanua Levu
# 2       28                 Adi                    Vanua Levu, Ami-Ami-CA
# 3       32  Akesson's (Pralus)  Bali (west), Sukrama Family, Melaya area
# 4       33  Akesson's (Pralus)               Madagascar, Ambolikapiky P.
# ..     ...                 ...                                       ...
# 790   1778              Zotter                                       Raw
# 791   1779              Zotter              Bocas del Toro, Cocabo Co-op
# 792   1784              Zotter                                    El Oro
# 793   1785              Zotter                              Huiwani Coop
# 794   1786              Zotter                             El Ceibo Coop
#
#      Review Date  Cocoa Percent Company Location  Rating  \
# ...
